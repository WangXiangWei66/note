# %% [markdown]
# # 1.1随机事件及其运算

# %% [markdown]
# 样本空间的大小：有限、无限可列、无限不可列
# #A,|A| ：集合中元素的个数
# 无限可列集合 < 无限不可列集合
# 随机变量：定义在样本空间上的实值函数X（W）
# 区间：[a,b] = {x:a$\leq$x$\leq$b}
#      (a,b) = {x:a$\lt$x$\lt$b}
# 域：集合的集合
# 集合类：集合的集合
# $\mathcal{F}$ = {事件....}

# %%
import numpy as np
import matplotlib.pyplot as plt
#处patches用于理各种图形的绘制，如矩形、圆形
from matplotlib.patches import Circle
# %matplotlib inline

# %%
#figure.dpi用于设置图形的每英寸点数
#本串代码用于设置图形的清晰度
plt.rcParams['figure.dpi'] = 300

# %%
plt.figure(figsize=(6, 6))

# %%
#fill = False 表示该圆形不填充颜色
#color = 'blue' 指定圆形线条颜色为蓝色；
#linewidth = 2 设置圆形线条宽度为 2 ；
#label = ' 单位圆 ' 为这个圆形对象添加了一个标签叫 “单位圆” ，
circle = Circle((0,0),1,fill = False, color = 'blue', linewidth = 2, label = '单位圆')

# %%
#add_patch方法专门用于向该坐标轴添加一个补丁（patch）对象
plt.gca().add_patch(circle)

# %%
#axhline:水平垂直线
ax.axhline(y=0, color = 'black', linestyle = '-', alpha=0.3)
#axvline:竖直垂直线
ax.axvline(x=0, color = 'black', linestyle ='-' ,alpha = 0.3)

# %%
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
ax.set_xticks(np.arange(-1.5, 1.6, 0.5))
ax.set_yticks(np.arange(-1.5, 1.6,0.5))

# %%
#True表示在子图上显示网格线
ax.grid(True, linestyle = '--', alpha = 0.6)

# %%
ax.set_title('单位圆示意图', fontsize=14)
#自动识别绘图中不同数据系列对应的标签，并在图表上合适位置添加一个图例，以帮助读者区分不同数据系列的含义
ax.legend()

# %%
#设置坐标轴的比例相等，使得圆看起来像圆
ax.set_aspect('equal')

# %%
#plt.tight_layout()的作用是自动调整子图参数，以确保图、标签、标题等元素都能合适地显示，避免相互重叠。
plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from io import BytesIO
plt.figure(figsize=(6, 6))
circle = plt.Circle((0, 0), 1, fill=False, color='blue', linewidth=2)
plt.gca().add_patch(circle)

# 设置坐标轴和网格
plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)
plt.axvline(x=0, color='black', linestyle='-', alpha=0.3)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.xticks(np.arange(-1.5, 1.6, 0.5))
plt.yticks(np.arange(-1.5, 1.6, 0.5))
plt.grid(True, linestyle='--', alpha=0.6)

# 设置标题和图例
plt.title('单位圆示意图')
plt.legend([circle], ['单位圆'])
plt.axis('equal')

plt.show()
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
